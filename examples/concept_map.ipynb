# %%
import cc.concept_map

# %% [markdown]
# # Load Existing Concept Map

# %%
cm = cc.concept_map.ConceptMap.load( './example_concept_map.hdf5' )

# %% [markdown]
# # Plot

# %%
fig = plt.figure( figsize=(17, 7), facecolor='w' )
ax = plt.gca()

cm.plot_relation_vs_weight(
    ax = ax,
#     y_jitter = 0.07,
    recursively_fix_overlaps = True,
)

# ax.set_xlim( 0.65, 1.05 )
# Out:
# Text(2,0.9,'circumgalactic\nmedium')

# %% [markdown]
# For interpretation, the farther a concept is to the right, the more important it is *within the context intended by the user*.
# The more concepts that have higher y-values for a given x-axis concept the more interconnected the x-axis concept is.

# %% [markdown]
# # Build a Concept Map from Scratch
# Run the below to build a concept map from scratch using User Input

# %%
concepts = [
    'interstellar medium',
    'galaxies',
    'circumgalactic medium',
    'intergalactic medium',
]

# %%
cm = cc.concept_map.ConceptMap( concepts )

# %%
cm.user_evaluation()
# Out:
# Please provide weights for the following.
# interstellar medium : q
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1e659cd5bc19> in <module>()
# ----> 1 cm.user_evaluation()
#
# /Users/zhafen/repos/cc/cc/concept_map.py in user_evaluation(self)
#     105         weights = {}
#     106         for concept in req_concepts:
# --> 107             weights[concept] = float( input( '{} :'.format( concept ) ) )
#     108
#     109         # Relations
#
# ValueError: could not convert string to float: 'q'

# %%
cm.save( './user_example_concept_map.hdf5' )
